# %% [markdown]
# # 第4章: 形態素解析

# %% [markdown]
# 夏目漱石の小説『吾輩は猫である』の文章（neko.txt）をMeCabを使って形態素解析し，その結果をneko.txt.mecabというファイルに保存せよ．このファイルを用いて，以下の問に対応するプログラムを実装せよ．
#
# なお，問題37, 38, 39はmatplotlibもしくはGnuplotを用いるとよい．

# %% [markdown]
# ## 目次
# * [30. 形態素解析結果の読み込み](#sec1)
# * [31. 動詞](#sec2)
# * [32. 動詞の原形](#sec3)
# * [33. サ変名詞](#sec4)
# * [34. AのB](#sec5)
# * [35. 名詞の連接](#sec6)
# * [36. 単語の出現頻度](#sec7)
# * [37. 頻出上位10語](#sec8)
# * [38. ヒストグラム](#sec9)
# * [39. Zipfの法則](#sec10)
#
# ## リンク
# 吾輩は猫である ([neko.txt](http://www.cl.ecei.tohoku.ac.jp/nlp100/data/neko.txt))
#
# ## MeCab
# 出力フォーマットは, **表層形\t品詞,品詞細分類1,品詞細分類2,品詞細分類3,活用型,活用形,原形,読み,発音**

# %%
# !mecab data/neko.txt -o work/neko.txt.mecab

# %%
# !head -n 20 work/neko.txt.mecab
# Out:
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# EOS
# EOS
# 　	記号,空白,*,*,*,*,　,　,
# 吾輩	名詞,代名詞,一般,*,*,*,吾輩,ワガハイ,ワガハイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 猫	名詞,一般,*,*,*,*,猫,ネコ,ネコ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# ある	助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
# 名前	名詞,一般,*,*,*,*,名前,ナマエ,ナマエ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# まだ	副詞,助詞類接続,*,*,*,*,まだ,マダ,マダ
# 無い	形容詞,自立,*,*,形容詞・アウオ段,基本形,無い,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
# EOS
# 　	記号,空白,*,*,*,*,　,　,
# どこ	名詞,代名詞,一般,*,*,*,どこ,ドコ,ドコ

# %% [markdown]
# # 30. 形態素解析結果の読み込み<a id="sec1"></a>
# 形態素解析結果（neko.txt.mecab）を読み込むプログラムを実装せよ．ただし，各形態素は表層形（surface），基本形（base），品詞（pos），品詞細分類1（pos1）をキーとするマッピング型に格納し，1文を形態素（マッピング型）のリストとして表現せよ．第4章の残りの問題では，ここで作ったプログラムを活用せよ．

# %%
from itertools import groupby
from pprint import pprint
neko = []
with open("work/neko.txt.mecab", "r") as f:
    for is_eos, sent_block in groupby(f, key=lambda x: x.strip() == "EOS"):
        if not is_eos:
            sentence = []
            for line in sent_block:
                details = line.rstrip().replace("\t", ",").split(",")
                morph = {
                    "surface": details[0],
                    "base": details[7],
                    "pos": details[1],
                    "pos1": details[2]
                }
                sentence.append(morph)
            neko.append(sentence)
pprint(neko[:3])
# Out:
# [[{'base': '一', 'pos': '名詞', 'pos1': '数', 'surface': '一'}],
#  [{'base': '\u3000', 'pos': '記号', 'pos1': '空白', 'surface': '\u3000'},
#   {'base': '吾輩', 'pos': '名詞', 'pos1': '代名詞', 'surface': '吾輩'},
#   {'base': 'は', 'pos': '助詞', 'pos1': '係助詞', 'surface': 'は'},
#   {'base': '猫', 'pos': '名詞', 'pos1': '一般', 'surface': '猫'},
#   {'base': 'だ', 'pos': '助動詞', 'pos1': '*', 'surface': 'で'},
#   {'base': 'ある', 'pos': '助動詞', 'pos1': '*', 'surface': 'ある'},
#   {'base': '。', 'pos': '記号', 'pos1': '句点', 'surface': '。'}],
#  [{'base': '名前', 'pos': '名詞', 'pos1': '一般', 'surface': '名前'},
#   {'base': 'は', 'pos': '助詞', 'pos1': '係助詞', 'surface': 'は'},
#   {'base': 'まだ', 'pos': '副詞', 'pos1': '助詞類接続', 'surface': 'まだ'},
#   {'base': '無い', 'pos': '形容詞', 'pos1': '自立', 'surface': '無い'},
#   {'base': '。', 'pos': '記号', 'pos1': '句点', 'surface': '。'}]]

# %% [markdown]
# ファイルが大きい場合があるので、ブラウザでダウンロードするよりもwgetでダウンロードする方が良い
# patterunはキャッシュされる
# 変数は小文字
# zip(range(),iterable) or isliceでheadのような動きができる
# 1行の最後の改行は悪さをする可能性がある rstrip()をする習慣を
# csvを処理する際には、import csvかpandasを使います
# replace("\t", ",").split(",")
# generaterとitetoolsで解くと良い

# %% [markdown]
# # 31.動詞<a id="sec2"></a>
# 動詞の表層形をすべて抽出せよ．

# %%
verb_surface = {word['surface'] for sentence in neko for word in sentence if word['pos'] == "動詞"}

# %% [markdown]
# # 32. 動詞の原形<a id="sec3"></a>
# 動詞の原形をすべて抽出せよ

# %%
# %%timeit
verb_surface = {word['base'] for sentence in neko for word in sentence if word['pos'] == "動詞"}
# Out:
# 10 loops, best of 3: 24.6 ms per loop

# %%
# %%timeit
from itertools import chain
verb_surface = {x["surface"] for x in chain.from_iterable(neko) if x["pos"] == "動詞"}
# Out:
# 10 loops, best of 3: 27.4 ms per loop

# %%
from itertools import chain
# %timeit verb_surface = {x["surface"] for x in chain.from_iterable(neko) if x["pos"] == "動詞"}
# Out:
# 10 loops, best of 3: 27.5 ms per loop

# %% [markdown]
# # 33. サ変名詞<a id="sec3"></a>
# サ変接続の名詞をすべて抽出せよ．

# %%
verb_surface = {word['base'] for sentence in neko for word in sentence if word['pos1'] == "サ変接続"}

# %% [markdown]
# # 34. 「AのB」<a id="sec4"></a>
# 2つの名詞が「の」で連結されている名詞句を抽出せよ

# %%
connected_no = {sentence[i]['surface'] + "の" + sentence[i+2]['surface'] 
             for sentence in neko 
                 for i in range(len(sentence) - 2) 
                     if all((sentence[i]['pos'] == "名詞", sentence[i+1]['surface'] == "の",
                         sentence[i+2]['pos'] == "名詞"))}

# %% [markdown]
# # 35. 名詞の連接<a id="sec5"></a>
# 名詞の連接（連続して出現する名詞）を最長一致で抽出せよ．

# %%
from itertools import groupby
connected_noun = set()
for sentence in neko:
    for is_noun, noun_block in groupby(sentence, lambda x: x['pos'] == "名詞"):
        if is_noun :
            nouns = list(noun_block) #一旦listで保存しないと, noun_blockがgroupby()とiterableを共有しているので×
            if len(nouns) > 1:
                connected_noun.add("".join(noun['surface'] for noun in nouns))
print(connected_noun)
# Out:
# {'とき頭', '扇使い', '豪奢風流', '聯隊長', '懐旧談', '全体どこ', '人間界', '書冊出版', '三歳', '頓珍漢的作用', '水島さん', '二分の一', '任意これ', '先生たいがい', '毎日事務', '畸形児', '二日間', '大分厭世的', '四本足', '汝何', '乙組中鏘', '——こっちの', '何だい新体詩', '一人', '一たび時機', '事局', 'じい勢', '不得要領底', '是非一丁', '猫誉信女南無阿弥陀仏南無阿弥陀仏', '考え違', '五六間', '学校時代', 'すべて人間', '三丁目', '蛸壺峠', '二十年', '富士見町', 'がんがらがんの', '男女間', '婚儀上', '麩海苔', '二寸', '頸根っこ', '此千古未曾有', '維新前', '関ら', '後進生', '自家固有', '——主人', '結果鼻', '写生文', '半月形', 'すべて今', '坊ば', 'お客さま', '八万八千八百八十本', '柿落葉', '十七', '喜多床', '十年間', '邸内', 'アハハハそれ', '庭内', '苦心惨憺', '教育上必要', '全智全能', '大方熊', '歯痕', '晩帰り', '昏睡仮死', '忍び入り', '度心得', '冷暖', '美学研究', '希臘', '先天的形体', '三毛子さん三毛子さん', '二人', '塊まり', 'さ一間', '鍛冶屋', '野蛮的蟷螂', 'どんと併', '昨夜寒月君', '木槿垣', '双方共頭', '——なに仲人', '行屎送尿', '八時', '八分通り', '二年乙組', 'ちょきちょき', '図案学校', '上り立て', '結果皮', '二世', '法とり', 'の何', '猫一疋', '結果不自由', '浴場内', '奇体', 'ちの蓋', '掛念', '一体医者', '灯自ら', '旧幕時代', '金田富子嬢', '七日間', '西郷隆盛君', '哲学者先生', 'ハハハハこれ', '文章言辞', '研究上', '物指', '吾妻橋事件', '君不思議', '衆目環視', '吾輩ども', 'ホホホホいや', '富時', 'ケース入り', '七割弱', '多々良さん', '痘痕面', '吾忠勇義烈', '一時其極', '上不思議', '五車', '臨時気違', '鰹節競争', '事——これ', '神秘的作用', '護身服', 'なんざあ年', '——猫なで声', '自覚心', '何だい', '一局', '一人前', '——先生披露会', '幾日', 'いく篇', '講釈師', 'アハハハハ別段難', '六尺', 'ウェルテル君', '十年一日', '料理屋', '巴理', '——」迷亭', '君何', '金田夫婦', '沙弥先生', '展覧会', '——奥さん', '勘公', '人間自然', '三四分', '十把一', '朱泥', '体量', '通人論', 'なに厭', '紅塵万丈', '固形体', '五十', '沢庵石', 'ひと度', '二銭五厘', '新年宴会', '二枚かけ', '温泉場', '振り損', '膏ぎって', '暮色蒼然', '一歳何ヵ月', 'ダムダム弾以上', '裸蝋燭', '張本金田君', '六つ井物産会社', '忽然豹変', '一生徒', '姫様', '書生体', '永久満足', '牡蠣先生', '十四五', '裏表共', '日本堤', '文学者', '綿入', '綿畠', '霊物', '鼻恋', '改良首きり器械', '君西洋人', '左右交', '候間', '何物たる', '全体何', '黒甜郷裡', '活画', '五円', '重太郎先生', '上の分', '毬栗君', '貴様等', 'それ以外', '注文通り二叉', '三番目', '油野郎', '国自慢', '当人同志', 'せんだって学校', '寺内', '大手柄', '瑣談繊話', '己霊', '神祇釈教恋無常', '疳違い', '伊勢源', '当分留守番', 'ハハハハじじい', '狆君', '君一つ譜', '日露戦争時代', '張り具合', '自信致候', '四はと', '手詰', '書生時代', '四望人', 'ままヴァイオリン', 'つけよう', '候饗宴', '諦らめ', '植木屋', '梧前灯下', '白牛', '水癲癇', '生薬屋', '○子さん', '一枚寒月君', '管轄内', 'みんな泥棒根性', '往む先生', '偶然童子', '一工夫', 'ごと勉強', '植物園', 'まま懐手', '羅馬', '出掛', '注文通り寒月君', '口返答', '猫食い', '癇違い', '末勢', '筋頭', '上げら', '独り語', '樹下石上', '二匹', '前途有望', '近所迷惑', '鴻溝', '鐘つき番', '滑稽文', 'ん訳', '規常道', '五年', '馬鹿気', 'ボーン', '白毛布', '付五升五合', '寒鴉', '一番利口', '戸迷', '二側', '兎さん', '腋下', '八時半頃', '苦沙弥君', '羽織全盛', '濠端', 'そりゃ訳', '石地蔵', '神田辺', '歴史家', '風態', '自覚性馬鹿', '沈澱組', '道具類', '時上', '通り寒月君', '動物園', '演芸矯風会', '寒厨何', '大変感じ', '万朝', '四十前後', '一杯目', '一つ二つ', '大分減', '金善方', '金田君', '世間的', '江戸趣味', '物外', '薫風南', '——人間', '忘年会兼合奏会', '為め熱誠之', '六百円', 'たき殻', '人釣白蘋紅蓼間', '三角術', '円滑円滑', '乗り廻わし', '何鼠', '顔中真赤', '迷惑千万', '——たま', 'エジプト人', '新聞屋', '本もの', '東京市民', '変出鱈目', '九十度', '三四梃一度', '一飯君恩', '原稿用紙', '毒悪', '四寸', 'あら猫', '按腹揉療治', '三日三晩手', 'これゃちょっと僕', '二十七日', '——末', '視線内', '粘着力', '南隣', '摺小木', '朱盆', '一番獰悪', '不徳事件', '大分県', '材料払底', '状体', '滑かな顔', '甲羅つき', '命令中', '二六時中間断', '燈国師', '昔しの人', '一番都合', '今日歓迎', 'ヴァイオリン談', '雪江さん何', '多々良君柄', '五六行', '神秘的', '十七味調唐辛子調', '彼等君子', '眼鏡越', 'なに猫', '四人', '異体同心', '大方居眠り', '毎日散歩', '猫大明神', '暫時中止', '一あなた', '朗読会', '猫児', '吾等', 'こま結び', 'あらら', '右眼', 'とき三円二十銭', '鈴木君', '根気負け', '三角主義', '——、これ', '箆棒', '三四十目', '福地さん', '大分物騒', '我儘者', '電話室', '迷亭先生', '気の毒さ', '局外者', '——何年前', 'ゴロツキ', 'すべて敵', '甘木さん', 'それぎりしか', '白粉罎', 'みんな静か', '十二月一日', 'ため逆上', '太人中', '二丁目', '活動図書館', '鈍液', '二分', '美的価値', '鹿爪', '三面攻撃', '思索力', 'おやじさん', '跣足', '一部隊', '両替町', 'Doyouseetheboy', '濡れ手拭', '一番毒', '一軒', '曰く天下', '仏師屋', '二尺四方', '美術的演芸', '六十七', '陽春白雪', '終夜顫えつ', '五六円', '現今英国', 'コルドヴァさ', 'その後野良', '何千万枚', '許さん', '金時計', '琴瑟調和', "manyaslip'twixtthecupandthelip", '三円', '皿眼', '一大要件', '——」「あらいや', 'ざあと旦那', 'ことこと', 'なに訳', '必竟自分', '己惚', '十七八', '古井何とか', '弥次馬兼援兵', '為め', '——幸いヴァイオリン', 'パナマ責め', '我知らず', '露華', '電気灯', '夜間外出', '雛鶏', 'ざる者', '兵式体操', '一自己', 'さ加減', '不思議そう', '是非固形体', '簀垂れ', '一息つき', '夜十一時頃', '二三日中', '種類如何', '商買道具', '時事問題', 'ガラス屋', '表章', 'その後吾輩', '灼然炳乎', '浮華虚栄', '裸体像', '文学美術', '六尺以上', '——もってのほか', '日中', '工芸上', '毎日奇麗', '敏腕家', '三日月形', '家伝来', '車引き', '大分充血', '警視庁刑事巡査吉田虎蔵', '君本物', '皇天憐', '二百五十円', '舞踏会', '剛慢', '先刻細君', '目刺', '一両度三毛子', '校舎新築費', '——これ', '存外自覚心', '享受者', '三代様', 'アルプス山', '蒸汽喞筒', '三四個月', '十二分の成績', '否大', 'けらけら', '美貌家', '招魂社', '卒業後図書館', '候次第', '指環', ' ...

# %% [markdown]
# # 36. 単語の出現頻度<a id="sec6"></a>
# 文章中に出現する単語とその出現頻度を求め，出現頻度の高い順に並べよ．

# %%
from collections import Counter

all_words = (word['base'] for sentence in neko for word in sentence)
count_words = Counter(all_words)
for _, word_count in zip(range(10), count_words.most_common()):
    print(word_count)
# Out:
# ('の', 9194)
# ('。', 7486)
# ('て', 6848)
# ('、', 6772)
# ('は', 6420)
# ('に', 6243)
# ('を', 6071)
# ('だ', 5975)
# ('と', 5508)
# ('が', 5337)

# %% [markdown]
# # 37. 頻度上位10語<a id="sec7"></a>
# 出現頻度が高い10語とその出現頻度をグラフ（例えば棒グラフなど）で表示せよ

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font='AppleMyungjo')

label, y = [], []
for word, i in count_words.most_common(10):
    label.append(word)
    y.append(i)
x = [i for i in range(10)]
plt.bar(x, y, tick_label =label, align="center")
plt.show()

# %% [markdown]
# # 38. ヒストグラム<a id="sec8"></a>
# 単語の出現頻度のヒストグラム（横軸に出現頻度，縦軸に出現頻度をとる単語の種類数を棒グラフで表したもの）を描け．

# %%
import matplotlib.pyplot as plt
y = [c for _, c in count_words.most_common()]
plt.hist(y,bins=10, log=True)
plt.show()

# %% [markdown]
# # 39. Zipfの法則<a id="sec9"></a>
# 単語の出現頻度順位を横軸，その出現頻度を縦軸として，両対数グラフをプロットせよ．

# %%
import matplotlib.pyplot as plt
freq = [c for _, c in count_words.most_common()]
uniq_freq = sorted(freq, reverse = True)
x = [i for i in range(len(uniq_freq))]
plt.loglog(x,uniq_freq)
plt.show()
